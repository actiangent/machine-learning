# %% [markdown]
# **Nama: Hisyam Fausta**
# **NIM: 20210801191**

# %% [markdown]
# Essay:
#
# 1. Jelaskan apa yang dimaksud dengan Machine Learning
# 2. Berikan contoh penerapan implemetasi dalam kehidupan sehari-hari terkait Machine Learning. Dan jelaskan mengapa membutuhkannya dan manfaatnya
# 3. Jelaskan macam-macam taxonomi dalam penerapan Machine Learning
#
# Jawaban:
# 1. Machine Learning adalah bidang studi yang termasuk dalam studi Artificial Intelligence yang berfokus pada pengembangan algoritma statistik yang memungkinkan komputer untuk melakukan tugas tanpa instruksi eksplisit dari manusia, melainkan berdasarkan pengalaman atau data yang ada.
# 2. Contoh penerapan Machine Learning dalam kehidupan sehari-hari:
#   * Analisis Sentimen: Bisnis menggunakan analisis sentimen untuk memahami perasaan dan opini pelanggan dari ulasan produk, komentar media sosial, dan umpan balik lainnya.
#   * Kesehatan: Dalam bidang kesehatan, machine learning digunakan untuk mendiagnosis penyakit berdasarkan data medis seperti hasil pemeriksaan, rekam medis pasien, dan gambar medis (misalnya, MRI atau CT scan). Algoritma ini membantu dokter membuat keputusan yang lebih baik dan lebih cepat.
#   * Rekomendasi yang dipersonalisasi: Situs e-commerce ataupun layanan streaming menggunakan algoritma machine learning untuk merekomendasikan produk atau konten kepada pengguna berdasarkan riwayat penelusuran dan preferensi mereka.
# 3. Taksonomi Machine Learning terbagi menjadi 3 kelompok utama:
#   1. Supervised Learning
#   Supervised learning adalah kategori di mana algoritma machine learning dilatih menggunakan data yang sudah diberi label yang berarti setiap input data disertai dengan output yang diinginkan. Tujuan dari supervised learning adalah untuk mempelajari hubungan atau fungsi yang memetakan input ke output berdasarkan contoh yang diberikan.
#   Contoh:
#     * Diagnostik Medis: Memprediksi apakah seorang pasien memiliki penyakit tertentu berdasarkan data medis mereka.
#   2. Unsupervised Learning
#   Unsupervised learning adalah kategori di mana algoritma dilatih menggunakan data yang tidak diberi label. Algoritma mencoba mempelajair data tanpa panduan dari output yang diinginkan.
#   Contoh:
#     * Segmentasi Pelanggan: Mengelompokkan pelanggan berdasarkan pola pembelian mereka untuk strategi pemasaran yang lebih efektif.
#   3. Reinforcement Learning
#   Reinforcement learning adalah metode di mana algoritma belajar melalui interaksi dengan lingkungan. Algoritma mendapatkan umpan balik dalam bentuk reward atau penalti berdasarkan tindakan yang diambil, dan tujuannya adalah untuk memaksimalkan total reward sepanjang waktu.
#   Contoh:
#     * Robotika: Mengajarkan robot untuk berjalan atau melakukan tugas tertentu melalui trial and error.

# %%
import math

import pandas as pd

# %% [markdown]
# Studi Kasus:

# %% [markdown]
# 1. Sempurnakan Data Set Universitas Esa Unggul memiliki detail mahasiswa sebagai berikut : Ani, Budi, Joni, Jono dan Lono Setiap mahasiswa dating ke kampus mulai dari hari senin sampai minggu Untuk melakukan kegiatan kuliah Ani menghabiskan biaya 30000 dikampus setiap datang Budi menghabiskan biaya 35000 dikampus setiap datang Joni menghabiskan biaya 20000 dikampus setiap datang Jono 25000 dan Lono 15000
#
#   a) Berapa rata-rata mahasiswa datang pada minggu ini?
#   b) Kapan biaya tertinggi terjadi?
#   c) Hari apa biaya lebih dari 110000?
#   d) Siapa yang paling banyak datang ke kampus?
#   e) Siapa yang datang pada hari minggu?
#   f) Berapa biaya tertinggi dan terendah?
#   g) Berapa frekuensi datang tertinggi dan
#   terendah?

# %%
dataset_student = {
    "Hari": ["Senin", "Selasa", "Rabu", "Kamis", "Jumat", "Sabtu", "Minggu"],
    "Datang": [2, 3, 4, 1, 2, 5 , 2],
    "Biaya": [30_000, 35_000, 25_000, 15_000, 20_000, 30_000, 35_000],
    "Mahasiswa": ["Ani", "Budi", "Jono", "Lono", "Joni", "Ani", "Budi"]
}

df = pd.DataFrame(dataset_student)
df
# Out:
#      Hari  Datang  Biaya Mahasiswa
# 0   Senin       2  30000       Ani
# 1  Selasa       3  35000      Budi
# 2    Rabu       4  25000      Jono
# 3   Kamis       1  15000      Lono
# 4   Jumat       2  20000      Joni
# 5   Sabtu       5  30000       Ani
# 6  Minggu       2  35000      Budi

# %%
df["Biaya"] = df["Biaya"] * df["Datang"]
df
# Out:
#      Hari  Datang   Biaya Mahasiswa
# 0   Senin       2   60000       Ani
# 1  Selasa       3  105000      Budi
# 2    Rabu       4  100000      Jono
# 3   Kamis       1   15000      Lono
# 4   Jumat       2   40000      Joni
# 5   Sabtu       5  150000       Ani
# 6  Minggu       2   70000      Budi

# %%
# Berapa rata-rata mahasiswa datang pada minggu ini?
mean_students_came_week = df["Datang"].mean()
print("Berapa rata-rata mahasiswa datang pada minggu ini?", str(mean_students_came_week), sep=" ")
floor_mean_students_came_week = math.floor(mean_students_came_week) # math.floor() untuk menghindari koma, pembulatan ke bawah
print("Berapa pembulatan rata-rata mahasiswa datang pada minggu ini?", str(floor_mean_students_came_week), sep=" ")
print("\n")

# Kapan biaya tertinggi terjadi?
max_cost_day = df.loc[df["Biaya"].idxmax(), "Hari"]
print("Kapan biaya tertinggi terjadi?", str(max_cost_day), sep=" ")
print("\n")

# Hari apa biaya lebih dari 110000?
day_more_than_110k = df.loc[df.index[df['Biaya'] > 110_000][0], "Hari"]
print("Hari apa biaya lebih dari 110000?", str(day_more_than_110k), sep=" ")
print("\n")

# Siapa yang paling banyak datang ke kampus?
comes_the_most = df.loc[df["Datang"].idxmax(), "Mahasiswa"]
print("Siapa yang paling banyak datang ke kampus?", str(comes_the_most), sep=" ")
print("\n")

# Siapa yang datang pada hari minggu?
comes_on_sunday = df.loc[df.index[df['Hari'] == "Minggu"][0], "Mahasiswa"]
print("Siapa yang datang pada hari minggu?", str(comes_on_sunday), sep=" ")
print("\n")

# Berapa biaya tertinggi dan terendah?
max_cost = df["Biaya"].max()
min_cost = df["Biaya"].min()
print("Berapa biaya tertinggi dan terendah?", "Biaya Tertinggi:", str(max_cost), "dan", "Biaya Terendah:", str(min_cost), sep=" ")
print("\n")

# Berapa frekuensi datang tertinggi dan terendah?
comes_most = df["Datang"].max()
comes_least = df["Datang"].min()
print("Berapa frekuensi datang tertinggi dan terendah?", "Datang Tertinggi:", str(comes_most), "kali", "dan", "Datang Terendah:", str(comes_least), "kali", sep=" ")
# Out:
# Berapa rata-rata mahasiswa datang pada minggu ini? 2.7142857142857144
# Berapa pembulatan rata-rata mahasiswa datang pada minggu ini? 2
#
#
# Kapan biaya tertinggi terjadi? Sabtu
#
#
# Hari apa biaya lebih dari 110000? Sabtu
#
#
# Siapa yang paling banyak datang ke kampus? Ani
#
#
# Siapa yang datang pada hari minggu? Budi
#
#
# Berapa biaya tertinggi dan terendah? Biaya Tertinggi: 150000 dan Biaya Terendah: 15000
#
#
# Berapa frekuensi datang tertinggi dan terendah? Datang Tertinggi: 5 kali dan Datang Terendah: 1 kali

# %% [markdown]
# 2. Histogram Jumlah Mahasiswa dalam Fakultas

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
dataset_faculty = {
    "Fakultas": ["Bisnis", "D3 Perhotelan", "ICT", "Ilmu Komunikasi", "Seni dan Desain"],
    "Jumlah Mahasiswa": [260, 28, 284, 465, 735],
    "Akreditasi": ["A", "A", "B", "A", "A"]
}

df = pd.DataFrame(dataset_faculty)
df
# Out:
#           Fakultas  Jumlah Mahasiswa Akreditasi
# 0           Bisnis               260          A
# 1    D3 Perhotelan                28          A
# 2              ICT               284          B
# 3  Ilmu Komunikasi               465          A
# 4  Seni dan Desain               735          A

# %%
df = df[["Fakultas", "Jumlah Mahasiswa"]]
df.replace("Ilmu Komunikasi", "Ilmu\nKomunikasi")

ax = df.plot.bar(x="Fakultas", y="Jumlah Mahasiswa", rot=0, color=["#F8766D", "#A3A500", "#00BF7D", "#00B0F6", "#E76BF3"])
